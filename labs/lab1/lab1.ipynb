# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tips = pd.read_csv("https://raw.githubusercontent.com/anly503/datasets/main/tips.csv")
sns.histplot(tips['total_bill'],  
  color='#34f6ff')
plt.show()

# %%
sns.set_palette('Accent')
sns.set_style("darkgrid")
sns.stripplot(x='day', y='total_bill',
  data=tips)
plt.show()

# %%
plt.style.use('seaborn-white') #<<
fig,ax=plt.subplots()
ax.plot(tips['tip'], tips['total_bill'],'.')
ax.set_xlabel('Tips')
ax.set_ylabel('Total bill')
plt.show()
# Out:
# C:\Users\Dan Lim\AppData\Local\Temp\ipykernel_15948\3391995243.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white') #<<

# %%
plt.style.use('fivethirtyeight') #<<
fig,ax=plt.subplots()
ax.plot(tips['tip'], tips['total_bill'],'.')
ax.set_xlabel('Tips')
ax.set_ylabel('Total bill')
plt.show()

# %%
import matplotlib as mpl
mpl.rcParams['axes.facecolor']= 'f0f0f0'
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['lines.linewidth']= 5
mpl.rcParams['xtick.labelsize'] = 24
mpl.rcParams['ytick.labelsize'] = 24

fig,ax=plt.subplots()
ax.plot(tips['tip'], tips['total_bill'],'.')
plt.show()

# %%
from pathlib import Path

cfgdir = mpl.get_configdir() # find your configuration folder
p = Path(cfgdir)
stylelib = (p / 'stylelib')
stylelib.mkdir(exist_ok=True)
path = stylelib / 'mycustomstyle.mplstyle' # create paths

path.write_text(''' # write into the file
axes.facecolor : f0f0f0
font.family : serif
lines.linewidth : 5
xtick.labelsize : 24
ytick.labelsize : 24
''')
# Out:
# 129

# %%
mpl.style.reload_library()
'mycustomstyle' in mpl.style.available
# Out:
# True

# %%
mpl.style.use(['ggplot','mycustomstyle'])
fig,ax=plt.subplots()
ax.plot(tips['tip'], tips['total_bill'],'.')
plt.show()

# %%
sorted(mpl.style.available)
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'mycustomstyle',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
mpl.style.use('fivethirtyeight')

# %%
import numpy as np
def doplot():
    fig, ax = plt.subplots(1,1, figsize=(5,5))
    t = np.linspace(-2*np.pi, 2*np.pi, 1000)
    x = np.linspace(0,14, 100)
    for i in range(1,7):
        ax.plot(x, np.sin(x+i*0.5)*(7-i))
    return ax
doplot();

# %%
mpl.style.use('default')
with mpl.style.context('ggplot'):
    ax = doplot()
    ax.set_title('ggplot style')
ax = doplot()
ax.set_title('default style')
# Out:
# Text(0.5, 1.0, 'default style')

# %%
from pathlib import Path

cfgdir = mpl.get_configdir()
p = Path(cfgdir)
stylelib = (p / 'stylelib')
stylelib.mkdir(exist_ok=True)
path = stylelib / 'mucustomstyle.mplstyle'

path.write_text('''
axes.facecolor : f0f0f0
font.family : serif
lines.linewidth : 5
xtick.labelsize : 24
ytick.labelsize : 24
''')
# Out:
# 107

# %%
mpl.style.reload_library()

with mpl.style.context(['ggplot','mycustomstyle']):
    doplot()

# %%
x = np.linspace(0,100,50)
y = np.random.uniform(low=0, high=10, size=50)

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,10/1.618))

ax1.scatter(x,y, c='red', marker='+')
ax2.bar(x,y);

# %%
fig, ax = plt.subplots(2,2, figsize = (10,12))
ax[0,0].bar(x,y)

ax[1,0].bar(x,y)

ax[0,1].scatter(x,y)
ax[1,1].plot(x)

ax[1,1].set_title('Plot 4')
# Out:
# Text(0.5, 1.0, 'Plot 4')

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2, figsize=(10,12))
ax1.scatter(x,y,c='red', marker='+')
ax2.bar(x,y)

ax3.scatter(x,y, marker='x')
ax4.barh(x,y)

ax4.set_title('Plot 4')

plt.subplots_adjust(wspace=0.5, hspace=1.0)

# %%
x = np.linspace(0,100,50)
y1 = np.random.normal(loc = 10, scale=2, size=10)
y2 = np.random.normal(loc=20, scale=2, size=10)

fig, ((ax1,ax2)) = plt.subplots(1,2, figsize=(10,7))

ax1.plot(y1)
ax2.plot(y2);

# %%
fig, ((ax1,ax2)) = plt.subplots(1,2, figsize=(10,7), sharey=True)

ax1.plot(y1)
ax2.plot(y2);

# %%
def set_size(width):
    """Set aesthetic figure dimensions following golden ratio

    Args:
        width (float): width of the figure in inches (what matplotlib uses)

    Returns:
        fig_dim (tuple): Dimensions of the figure in inches
    """
    golden_ratio = (5 ** 0.5 -1)/2
    fig_height = width * golden_ratio

    return width, fig_height

# %%
x = np.linspace(0,10,num=1000)
fig, ax = plt.subplots(figsize = set_size(10))
ax.plot(x, np.sin(x))
plt.show()
